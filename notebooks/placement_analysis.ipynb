# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('campus_placement_data (1).csv')

# %%
df.head()
# Out:
#   student_id  gender  age city_tier  ssc_percentage ssc_board  hsc_percentage  \
# 0  STU000001    Male   22    Tier 1           71.01     State           76.76
# 1  STU000002  Female   22    Tier 2           58.46      CBSE           57.62
# 2  STU000003  Female   21    Tier 1           67.83      CBSE           65.67
# 3  STU000004  Female   21    Tier 2           80.40      CBSE           77.15
# 4  STU000005    Male   21    Tier 1           66.10     State           62.81
#
#   hsc_board hsc_stream  degree_percentage  ... technical_skills_score  \
# 0      CBSE   Commerce              64.44  ...                    6.8
# 1     State    Science              68.24  ...                    4.6
# 2     State   Commerce              52.33  ...                    4.7
# 3     State    Science              56.55  ...                    6.8
# 4      ICSE    Science              78.93  ...                    7.0
#
#    soft_skills_score aptitude_score  communication_score  \
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'age', 'city_tier', 'ssc_percentage',
#        'ssc_board', 'hsc_percentage', 'hsc_board', 'hsc_stream',
#        'degree_percentage', 'degree_field', 'mba_percentage', 'specialization',
#        'internships_count', 'projects_count', 'certifications_count',
#        'technical_skills_score', 'soft_skills_score', 'aptitude_score',
#        'communication_score', 'work_experience_months', 'leadership_roles',
#        'extracurricular_activities', 'backlogs', 'placed', 'salary_lpa'],
#       dtype='object')

# %%
 df = df.drop(['student_id' , 'salary_lpa' , 'specialization'], axis = 1)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'city_tier', 'ssc_percentage', 'ssc_board',
#        'hsc_percentage', 'hsc_board', 'hsc_stream', 'degree_percentage',
#        'degree_field', 'mba_percentage', 'internships_count', 'projects_count',
#        'certifications_count', 'technical_skills_score', 'soft_skills_score',
#        'aptitude_score', 'communication_score', 'work_experience_months',
#        'leadership_roles', 'extracurricular_activities', 'backlogs', 'placed'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                        0
# age                           0
# city_tier                     0
# ssc_percentage                0
# ssc_board                     0
# hsc_percentage                0
# hsc_board                     0
# hsc_stream                    0
# degree_percentage             0
# degree_field                  0
# mba_percentage                0
# internships_count             0
# projects_count                0
# certifications_count          0
# technical_skills_score        0
# soft_skills_score             0
# aptitude_score                0
# communication_score           0
# work_experience_months        0
# leadership_roles              0
# extracurricular_activities    0
# backlogs                      0
# placed                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (100000, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   gender                      100000 non-null  object
#  1   age                         100000 non-null  int64
#  2   city_tier                   100000 non-null  object
#  3   ssc_percentage              100000 non-null  float64
#  4   ssc_board                   100000 non-null  object
#  5   hsc_percentage              100000 non-null  float64
#  6   hsc_board                   100000 non-null  object
#  7   hsc_stream                  100000 non-null  object
#  8   degree_percentage           100000 non-null  float64
#  9   degree_field                100000 non-null  object
#  10  mba_percentage              100000 non-null  float64
#  11  internships_count           100000 non-null  int64
#  12  projects_count              100000 non-null  int64
# ...

# %%
df['placed'].value_counts()
# Out:
# placed
# 1    84432
# 0    15568
# Name: count, dtype: int64

# %%
df = df.replace(['Female','Male' ,'Other'] , [0,1,2])
# Out:
# C:\Users\YASH\AppData\Local\Temp\ipykernel_28664\935785271.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(['Female','Male' ,'Other'] , [0,1,2])

# %%
df.head()
# Out:
#    gender  age city_tier  ssc_percentage ssc_board  hsc_percentage hsc_board  \
# 0       1   22    Tier 1           71.01     State           76.76      CBSE
# 1       0   22    Tier 2           58.46      CBSE           57.62     State
# 2       0   21    Tier 1           67.83      CBSE           65.67     State
# 3       0   21    Tier 2           80.40      CBSE           77.15     State
# 4       1   21    Tier 1           66.10     State           62.81      ICSE
#
#   hsc_stream  degree_percentage degree_field  ...  certifications_count  \
# 0   Commerce              64.44  Engineering  ...                     2
# 1    Science              68.24     Business  ...                     2
# 2   Commerce              52.33  Engineering  ...                     2
# 3    Science              56.55  Engineering  ...                     3
# 4    Science              78.93  Engineering  ...                     2
#
#    technical_skills_score  soft_skills_score  aptitude_score  \
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# 1    55027
# 0    43028
# 2     1945
# Name: count, dtype: int64

# %%
sns.countplot( x = 'placed' , data = df)
# Out:
# <Axes: xlabel='placed', ylabel='count'>

# %%
numeric_df = df.select_dtypes(include=['int64' ,'float64'])
numeric_df.head()
# Out:
#    gender  age  ssc_percentage  hsc_percentage  degree_percentage  \
# 0       1   22           71.01           76.76              64.44
# 1       0   22           58.46           57.62              68.24
# 2       0   21           67.83           65.67              52.33
# 3       0   21           80.40           77.15              56.55
# 4       1   21           66.10           62.81              78.93
#
#    mba_percentage  internships_count  projects_count  certifications_count  \
# 0             0.0                  1               2                     2
# 1             0.0                  1               1                     2
# 2             0.0                  4               3                     2
# 3             0.0                  2               3                     3
# 4             0.0                  1               4                     2
#
#    technical_skills_score  soft_skills_score  aptitude_score  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(),annot=False , cmap = 'coolwarm')
plt.title('correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'correlation Heatmap')

# %%
sns.boxplot(x='placed' , y = 'degree_percentage' , data=df)
# Out:
# <Axes: xlabel='placed', ylabel='degree_percentage'>

# %%
sns.boxplot(x='placed' , y='technical_skills_score' , data = df)
# Out:
# <Axes: xlabel='placed', ylabel='technical_skills_score'>

# %%
df.hist(figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'ssc_percentage'}>,
#         <Axes: title={'center': 'hsc_percentage'}>],
#        [<Axes: title={'center': 'degree_percentage'}>,
#         <Axes: title={'center': 'mba_percentage'}>,
#         <Axes: title={'center': 'internships_count'}>,
#         <Axes: title={'center': 'projects_count'}>],
#        [<Axes: title={'center': 'certifications_count'}>,
#         <Axes: title={'center': 'technical_skills_score'}>,
#         <Axes: title={'center': 'soft_skills_score'}>,
#         <Axes: title={'center': 'aptitude_score'}>],
#        [<Axes: title={'center': 'communication_score'}>,
#         <Axes: title={'center': 'work_experience_months'}>,
#         <Axes: title={'center': 'leadership_roles'}>,
#         <Axes: title={'center': 'extracurricular_activities'}>],
#        [<Axes: title={'center': 'backlogs'}>,
# ...

# %%
df = pd.get_dummies(df, drop_first=True , dtype=int )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   gender                      100000 non-null  int64
#  1   age                         100000 non-null  int64
#  2   ssc_percentage              100000 non-null  float64
#  3   hsc_percentage              100000 non-null  float64
#  4   degree_percentage           100000 non-null  float64
#  5   mba_percentage              100000 non-null  float64
#  6   internships_count           100000 non-null  int64
#  7   projects_count              100000 non-null  int64
#  8   certifications_count        100000 non-null  int64
#  9   technical_skills_score      100000 non-null  float64
#  10  soft_skills_score           100000 non-null  float64
#  11  aptitude_score              100000 non-null  float64
# ...

# %%
df.head()
# Out:
#    gender  age  ssc_percentage  hsc_percentage  degree_percentage  \
# 0       1   22           71.01           76.76              64.44
# 1       0   22           58.46           57.62              68.24
# 2       0   21           67.83           65.67              52.33
# 3       0   21           80.40           77.15              56.55
# 4       1   21           66.10           62.81              78.93
#
#    mba_percentage  internships_count  projects_count  certifications_count  \
# 0             0.0                  1               2                     2
# 1             0.0                  1               1                     2
# 2             0.0                  4               3                     2
# 3             0.0                  2               3                     3
# 4             0.0                  1               4                     2
#
#    technical_skills_score  ...  ssc_board_ICSE  ssc_board_State  \
# ...

# %%
x = df.drop('placed' , axis = 1)
y = df['placed']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42 , stratify=y)

# %%
x_train.head()
# Out:
#        gender  age  ssc_percentage  hsc_percentage  degree_percentage  \
# 93783       1   23           75.54           72.91              90.82
# 33779       0   23           72.19           75.62              89.17
# 73983       1   21           58.68           65.14              60.43
# 75295       0   21           79.41           99.75             100.00
# 76961       1   20           70.94           76.27              71.78
#
#        mba_percentage  internships_count  projects_count  \
# 93783            0.00                  2               2
# 33779            0.00                  0               3
# 73983           80.83                  1               3
# 75295            0.00                  2               2
# 76961           71.57                  5               2
#
#        certifications_count  technical_skills_score  ...  ssc_board_ICSE  \
# 93783                     1                     5.0  ...               0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(x_train , y_train)
# Out:
# C:\Users\YASH\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.85845

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test , y_pred)
cm
# Out:
# array([[  782,  2332],
#        [  499, 16387]], dtype=int64)

# %%
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
plt.xlable('Predicted')
plt.ylable('Actual')
plt.title('Confusion Matrix')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[162], line 2
#       1 sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
# ----> 2 plt.xlable('Predicted')
#       3 plt.ylable('Actual')
#       4 plt.title('Confusion Matrix')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(n_estimators=100 , random_state=42)
model_rf.fit(x_train , y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = model_rf.predict(x_test)

# %%
rf_accoracy = accuracy_score(y_test , rf_pred)
rf_accoracy
